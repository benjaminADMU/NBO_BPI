# %%
import pandas as pd

# Assuming 'your_file.parquet' is the path to your Parquet file
df = pd.read_csv('Files\Product Flag Datasets\Product Flags\Products.csv',header=0)
df
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\P'
# <>:4: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\Dane\AppData\Local\Temp\ipykernel_20704\1627194561.py:4: SyntaxWarning: invalid escape sequence '\P'
#   df = pd.read_csv('Files\Product Flag Datasets\Product Flags\Products.csv',header=0)
#     Product_ID                      Product_Name                    Category
# 0            0            Corporate Credit Cards             CORPORATE_CARDS
# 1            1   Corporate Credit Cards - Credit             CORPORATE_CARDS
# 2            2  Corporate Credit Cards - Prepaid             CORPORATE_CARDS
# 3            3                        Auto loans             RETAIL_PRODUCTS
# 4            4                     Housing loans             RETAIL_PRODUCTS
# 5            5                    Personal loans             RETAIL_PRODUCTS
# 6            6                       Other loans             RETAIL_PRODUCTS
# ...

# %%
# Add new columns with null values
df['Region'] = None
df['Province'] = ''
df['Age'] = ''
df['Tenure'] = ''
df['Business_Owner'] = ''
df['Digital_Flag'] = ''
df['Income_Source'] = ''
df['Subsegment'] = ''
df['Idv_Or_Org'] = ''
df['Gender'] = ''
df['Marital_Status'] = ''

# %%
df
# Out:
#     Product_ID                      Product_Name                    Category  \
# 0            0            Corporate Credit Cards             CORPORATE_CARDS
# 1            1   Corporate Credit Cards - Credit             CORPORATE_CARDS
# 2            2  Corporate Credit Cards - Prepaid             CORPORATE_CARDS
# 3            3                        Auto loans             RETAIL_PRODUCTS
# 4            4                     Housing loans             RETAIL_PRODUCTS
# 5            5                    Personal loans             RETAIL_PRODUCTS
# 6            6                       Other loans             RETAIL_PRODUCTS
# 7            7                       Trade loans             CORPORATE_LOANS
# 8            8                           Leasing             CORPORATE_LOANS
# 9            9                   Operating lease             CORPORATE_LOANS
# 10          10                     RPNL/STL/KNCL             CORPORATE_LOANS
# ...

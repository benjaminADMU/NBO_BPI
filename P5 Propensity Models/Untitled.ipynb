# %%
import pandas as pd

# %%
pd.read_parquet('../Data/BIZKO/BIZKO FINANCIAL TRANSACTIONS.parquet')
# Out:
#          CUST_NUM              SERVICE CURRENCY      STATUS TRANSACTION_DATE  \
# 0     1923.232695         Subscription      PHP      Active       04/27/2023
# 1     2693.685579         Subscription      PHP      Active       04/11/2023
# 2     3579.458060         Subscription      PHP      Active       04/28/2023
# 3     3716.743467         Subscription      PHP      Active       04/21/2023
# 4     4001.697390         Subscription      PHP      Active       04/21/2023
# ..            ...                  ...      ...         ...              ...
# 195  13399.767908        Pay Employees      PHP  Successful       03/01/2024
# 196  13399.767908        Pay Employees      PHP  Successful       03/27/2024
# 197  13399.767908        Pay Employees      PHP  Successful       03/01/2024
# 198  13636.331691   Same Bank Transfer      PHP  Successful       03/22/2024
# 199  13636.331691  Other Bank Transfer      PHP  Successful       03/21/2024
#
# ...

# %%
pd.read_parquet('../Data/BIZKO/BIZKO AUDIT LOGS.parquet')
# Out:
#          CUST_NUM  TRANSACTION_DESCRIPTION    LOG_DATE  \
# 0     1923.232695        Online Enrollment  04/27/2023
# 1     1923.232695                    Login  04/27/2023
# 2     1923.232695                    Promo  04/27/2023
# 3     1923.232695      Enrollment Referral  04/27/2023
# 4     1923.232695                   Logout  04/27/2023
# ..            ...                      ...         ...
# 392  13101.641958                   Logout  03/22/2024
# 393  13101.641958            User Activity  03/22/2024
# 394  13101.641958            User Activity  03/22/2024
# 395  13101.641958                    Login  03/22/2024
# 396  13101.641958  Fraud Management System  03/22/2024
#
#           AUDIT_DETAIL_PROMO
# 0                       None
# 1                       None
# 2    Promo Code = BPIBIZKO\n
# 3                       None
# 4                       None
# ..                       ...
# 392                     None
# 393                     None
# 394                     None
# ...
